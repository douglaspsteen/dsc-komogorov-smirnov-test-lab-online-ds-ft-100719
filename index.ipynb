# %% [markdown]
# # The Kolmogorov-Smirnov Test - Lab

# %% [markdown]
# ## Introduction
# In the previous lesson, we saw that the Kolmogorov–Smirnov statistic quantifies a distance between the empirical distribution function of the sample and the cumulative distribution function of the reference distribution, or between the empirical distribution functions of two samples. In this lab, we shall see how to perform this test in Python.
#
# ## Objectives
#
# In this lab you will:
#
# - Calculate a one- and two-sample Kolmogorov-Smirnov test
# - Interpret the results of a one- and two-sample Kolmogorov-Smirnov test
# - Compare K-S test to visual approaches for testing for normality assumption

# %% [markdown]
# ### Data
#
# Let's import the necessary libraries and generate some data. Run the following cell:

# %%
import scipy.stats as stats
import statsmodels.api as sm
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('ggplot')

# Create the normal random variables with mean 0, and sd 3
x_10 = stats.norm.rvs(loc=0, scale=3, size=10)
x_50 = stats.norm.rvs(loc=0, scale=3, size=50)
x_100 = stats.norm.rvs(loc=0, scale=3, size=100)
x_1000 = stats.norm.rvs(loc=0, scale=3, size=1000)

# %% [markdown]
# ### Plots
#
# Plot histograms and Q-Q plots of above datasets and comment on the output
#
# - How good are these techniques for checking normality assumptions?
# - Compare both these techniques and identify their limitations/benefits etc.

# %%
# Plot histograms and Q-Q plots for above datasets
# x_10

plt.hist(x_10)
plt.show();
sm.qqplot(x_10, line='45', fit=True)
plt.show();

# x_50
plt.hist(x_50)
plt.show();
sm.qqplot(x_50, line='45', fit=True)
plt.show();

# x_100
plt.hist(x_100)
plt.show();
sm.qqplot(x_100, line='45', fit=True)
plt.show();

# x_1000
plt.hist(x_1000)
plt.show();
sm.qqplot(x_1000, line='45', fit=True)
plt.show();

# %%
# At n=10, we do not have anything resembling a normal distribution on the histogram or q-q plot.

# As sample size increases, it is easier to visualize a normal distribution on the histograms. It is also
# easier to see whether the shape is consistent with a normal distribution based on the q-q plots.
# The limitation of both of these plots is that they are qualitative - they can tell us whether a distribution
# "appears" normal, but they do not give a quantitative assessemtn of the normality of a distribution.

# %% [markdown]
# ### Create a function to plot the normal CDF and ECDF for a given dataset
# - Create a function to generate an empirical CDF from data
# - Create a normal CDF using the same mean = 0 and sd = 3, having the same number of values as data

# %%
# You code here 

def ks_plot(data):
    y = np.linspace(0, 1, num=len(data))
    x = np.sort(data)
    
    x_norm = np.sort(stats.norm.rvs(loc=0, scale=3, size=len(data)))
    
    plt.figure()
    plt.plot(x, y, label='ECDF')
    plt.plot(x_norm, y, label='CDF')
    plt.legend()
    plt.title(f'Comparing CDFs for KS-Test, Sample size = {len(data)}')
    plt.show;
    
    
# Uncomment below to run the test
ks_plot(stats.norm.rvs(loc=0, scale=3, size=100)) 
ks_plot(stats.norm.rvs(loc=2, scale=3.5, size=100))

# %% [markdown]
# This is awesome. The difference between the two CDFs in the second plot shows that the sample did not come from the distribution which we tried to compare it against.
#
# Now you can run all the generated datasets through the function `ks_plot()` and comment on the output.

# %%
ds = [x_10, x_50, x_100, x_1000]

for i in ds:
    ks_plot(i)

# %%
# As sample size increases, the shape of the ECDF more closely approximates the normal distribution CDF

# %% [markdown]
# ### K-S test in SciPy

# %% [markdown]
# Let's run the Kolmogorov-Smirnov test, and use some statistics to get a final verdict on normality. We will test the hypothesis that the sample is a part of the standard t-distribution. In SciPy, we run this test using the function below:
#
# ```python
# scipy.stats.kstest(rvs, cdf, args=(), N=20, alternative='two-sided', mode='approx')
# ```
# Details on arguments being passed in can be viewed at this [link to the official doc.](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.kstest.html)

# %% [markdown]
# Run the K-S test for normality assumption using the datasets created earlier and comment on the output:
# - Perform the K-S test against a normal distribution with mean = 0 and sd = 3
# - If p < .05 we can reject the null hypothesis and conclude our sample distribution is not identical to a normal distribution

# %%
# Perform K-S test 

for i in ds:
    print (stats.kstest(i, 'norm', args=(0, 3)))

# KstestResult(statistic=0.1377823669421559, pvalue=0.9913389045954595)
# KstestResult(statistic=0.13970573965633104, pvalue=0.2587483380087914)
# KstestResult(statistic=0.0901015276393986, pvalue=0.37158535281797134)
# KstestResult(statistic=0.030748345486274697, pvalue=0.29574612286614443)
# Out:
# KstestResult(statistic=0.19891097231588756, pvalue=0.8237006991947399)
# KstestResult(statistic=0.10777493046276804, pvalue=0.5838217861994844)
# KstestResult(statistic=0.06506062282978964, pvalue=0.7910735404076603)
# KstestResult(statistic=0.022616167789331953, pvalue=0.6858290051426723)

# %%
# The statistic (max difference between distributions) gets larger as sample size increases. p-value is > 0.05
# in every case, therefore we correctly accept the null hypothesis.

# %% [markdown]
# Generate a uniform distribution and plot / calculate the K-S test against a uniform as well as a normal distribution:

# %%
x_uni = np.random.rand(1000)
# Try with a uniform distribution
print(stats.kstest(x_uni, 'uniform'))
print(stats.kstest(x_uni, 'norm', args=(0,3)))
# KstestResult(statistic=0.023778383763166322, pvalue=0.6239045200710681)
# KstestResult(statistic=0.5000553288071681, pvalue=0.0)
# Out:
# KstestResult(statistic=0.023721673194265325, pvalue=0.6269226551574061)
# KstestResult(statistic=0.5002491924304955, pvalue=6.028878506199194e-232)

# %%
# The k-test indicates that the randomly generated uniform distribution is not statistically different
# than a uniform distribution, but we clearly reject this null hypothesis for a normal distribution.

# %% [markdown]
# ## Two-sample K-S test
#
# A two-sample K-S test is available in SciPy using following function:
#
# ```python
# scipy.stats.ks_2samp(data1, data2)[source]
# ```
#
# Let's generate some bi-modal data first for this test:

# %%
# Generate binomial data
N = 1000
x_1000_bi = np.concatenate((np.random.normal(-1, 1, int(0.2 * N)), np.random.normal(5, 1, int(0.8 * N))))[:, np.newaxis]
plt.hist(x_1000_bi);

# %% [markdown]
# Plot the CDFs for `x_1000_bimodal` and `x_1000` and comment on the output.

# %%
# Plot the CDFs
def ks_plot_2sample(data_1, data_2):
    '''
    Data entered must be the same size.
    '''
    y1 = np.linspace(0, 1, num=len(data_1))
    y2 = np.linspace(0, 1, num=len(data_2))
    x1 = np.sort(data_1)
    x2 = np.sort(data_2)
    
    plt.figure()
    plt.plot(x1, y1, label='Data_1')
    plt.plot(x2, y2, label='Data_2')
    plt.legend()
    plt.title('Comparing 2 CDFs for KS-Test')
    plt.show();
    
    

# Uncomment below to run
ks_plot_2sample(x_1000, x_1000_bi[:,0])

# %%
# You comments here 
# There is clearly a large difference in the cdfs for a binomial distribution and the normal distribution

# %% [markdown]
# Run the two-sample K-S test on `x_1000` and `x_1000_bi` and comment on the results.

# %%
# Two sample K-S test on x_1000 and x_1000_bi
print(stats.ks_2samp(x_1000, x_1000_bi[:,0]))
# Ks_2sampResult(statistic=0.633, pvalue=4.814801487740621e-118)
# Out:
# Ks_2sampResult(statistic=0.635, pvalue=1.1875381285669299e-189)

# %%
# With a large statistic and p_value of "effectively" zero, we can reject the null hypothesis that the two distributions
# are identical.
# Out:
# array([[-1.58864584e-01],
#        [-2.09597717e+00],
#        [-1.52016847e+00],
#        [-1.52534350e-01],
#        [-9.34590591e-01],
#        [ 1.18278690e+00],
#        [-1.09089877e+00],
#        [-1.96964837e-01],
#        [-2.52512335e+00],
#        [ 9.75715541e-01],
#        [ 1.44611483e-01],
#        [ 9.15285070e-02],
#        [ 2.64147454e-02],
#        [-6.88535181e-01],
#        [-1.46978175e+00],
#        [-1.71179368e+00],
#        [-4.57929194e-01],
#        [-4.85347376e-01],
#        [-1.23377074e+00],
#        [-1.59545177e+00],
#        [-4.95156477e-01],
#        [-1.62518612e+00],
#        [-1.80047860e+00],
#        [-1.44525317e-01],
#        [-6.58038109e-01],
#        [-1.10731635e+00],
#        [ 1.27641696e-01],
#        [-3.98163169e-01],
#        [-2.99270717e-01],
#        [-2.57593463e+00],
#        [-3.05979688e+00],
#        [-2.07890464e+00],
#        [-6.88106148e-01],
#        [-7.48170111e-01],
#        [ 5.76672993e-01],
#        [-1.64061443e+00],
#        [-7.04463709e-01],
#        [ 2.91175585e-01],
#        [-1.25314863e+00],
#        [ 6.42161042e-01],
#        [ 4.51209395e-01],
#        [-1.64379254e+00],
#        [-2.21071501e+00],
#        [-1.08693176e+00],
#        [ 8.95593787e-02],
#        [-7.35978236e-01],
#        [-1.63849415e+00],
#        [-2.29807249e+00],
#        [ 6.75313124e-02],
#        [-2.21318122e+00],
#        [-2.90768532e-01],
#        [-1.16283512e+00],
#        [-3.18289013e+00],
#        [-7.72932007e-01],
#        [-7.51943613e-01],
#        [-1.80328299e+00],
#        [-2.24909260e+00],
#        [-2.34341702e+00],
#        [ 1.08942020e-01],
#        [-1.86956625e+00],
#        [ 3.84116804e-01],
#        [-2.31339549e+00],
#        [-1.40749418e+00],
#        [-2.15250004e-01],
#        [-2.12274395e+00],
#        [ 7.24154506e-01],
#        [-5.16523437e-01],
#        [-2.73838793e-01],
#        [-8.10483913e-01],
#        [ 1.69159782e-01],
#        [-2.16276307e+00],
#        [-1.06579011e+00],
#        [-2.13272020e+00],
#        [-1.18107284e+00],
#        [-3.50584003e-01],
#        [ 1.87113487e-01],
#        [-2.16603808e+00],
#        [-9.07373819e-01],
#        [-1.35375843e+00],
#        [-1.99472250e+00],
#        [ 4.29671525e-01],
#        [-2.03492484e+00],
#        [-8.09659419e-01],
#        [-2.05786052e-01],
#        [-6.36352285e-01],
#        [-3.96320059e+00],
#        [ 6.66705051e+00],
#        [ 5.31237379e+00],
#        [ 4.53341360e+00],
#        [ 3.65072087e+00],
#        [ 4.10075703e+00],
#        [ 5.94649987e+00],
#        [ 2.15133540e+00],
#        [ 4.95318368e+00],
#        [ 6.31693830e+00],
#        [ 4.19256152e+00],
#        [ 4.86976522e+00],
#        [ 6.37910963e+00],
#        [ 6.06206936e+00],
#        [ 3.73480986e+00],
#        [ 3.56702099e+00],
#        [ 5.33870044e+00],
#        [ 5.42111740e+00],
#        [ 4.79713035e+00],
#        [ 4.58955380e+00],
#        [ 3.64819339e+00],
#        [ 5.21916471e+00],
#        [ 5.09034260e+00],
#        [ 3.69557503e+00],
#        [ 3.85002726e+00],
#        [ 4.41815557e+00],
#        [ 3.04011413e+00],
#        [ 6.63918812e+00],
#        [ 6.43856487e+00],
#        [ 5.80388751e+00],
#        [ 5.36614898e+00],
#        [ 4.12247781e+00],
#        [ 5.74389184e+00],
#        [ 4.06026434e+00],
#        [ 5.12986541e+00],
#        [ 4.62297900e+00],
#        [ 5.50201866e+00],
#        [ 3.01894200e+00],
#        [ 4.28929603e+00],
#        [ 3.15872583e+00],
#        [ 5.32767185e+00],
#        [ 3.81171175e+00],
#        [ 5.52890967e+00],
#        [ 3.50142436e+00],
#        [ 4.74558097e+00],
#        [ 3.60730714e+00],
#        [ 3.77985007e+00],
#        [ 5.59836205e+00],
#        [ 5.93769710e+00],
#        [ 4.38486357e+00],
#        [ 4.07785378e+00],
#        [ 5.70212474e+00],
#        [ 5.48146754e+00],
#        [ 5.16559676e+00],
#        [ 4.26292921e+00],
#        [ 5.49071412e+00],
#        [ 4.05063932e+00],
#        [ 5.01665592e+00],
#        [ 5.43419413e+00],
#        [ 4.77074586e+00],
#        [ 5.68205586e+00],
#        [ 5.09383920e+00],
#        [ 5.04048168e+00],
#        [ 4.56088879e+00],
#        [ 6.04271274e+00],
#        [ 3.77906693e+00],
#        [ 5.13420050e+00],
#        [ 4.68619593e+00],
#        [ 7.02570565e+00],
#        [ 4.92468202e+00],
#        [ 4.35584892e+00],
#        [ 5.46086980e+00],
#        [ 4.96835720e+00],
#        [ 4.19679437e+00],
#        [ 5.14026353e+00],
#        [ 3.79308413e+00],
#        [ 6.46028757e+00],
#        [ 5.71911194e+00],
#        [ 4.46467288e+00],
#        [ 2.14498792e+00],
#        [ 4.35110395e+00],
#        [ 3.89936193e+00],
#        [ 5.51376873e+00],
#        [ 2.35879326e+00],
#        [ 5.07883442e+00],
#        [ 5.51581687e+00],
#        [ 6.28517124e+00],
#        [ 4.16618556e+00],
#        [ 3.40692055e+00],
#        [ 5.32461303e+00],
#        [ 4.27401812e+00],
#        [ 5.66840716e+00],
#        [ 5.31197424e+00],
#        [ 4.43413400e+00],
#        [ 6.16789048e+00],
#        [ 5.85858600e+00],
#        [ 4.90347469e+00],
#        [ 5.15740840e+00],
#        [ 5.37440252e+00],
#        [ 6.55021388e+00],
#        [ 4.79922185e+00],
#        [ 6.90228768e+00],
#        [ 4.30620608e+00],
#        [ 3.51510623e+00],
#        [ 3.19397067e+00],
#        [ 5.26329233e+00],
#        [ 4.02509659e+00],
#        [ 4.12569490e+00],
#        [ 5.13601745e+00],
#        [ 5.09257181e+00],
#        [ 4.88303189e+00],
#        [ 4.09857183e+00],
#        [ 3.76814504e+00],
#        [ 5.69545135e+00],
#        [ 6.08332450e+00],
#        [ 4.63663077e+00],
#        [ 5.74173250e+00],
#        [ 4.51068314e+00],
#        [ 4.43594460e+00],
#        [ 5.99757210e+00],
#        [ 4.44082970e+00],
#        [ 4.85294812e+00],
#        [ 4.70326355e+00],
#        [ 6.48151184e+00],
#        [ 6.31131092e+00],
#        [ 3.93706311e+00],
#        [ 3.33048733e+00],
#        [ 4.91215982e+00],
#        [ 5.07988063e+00],
#        [ 6.09392159e+00],
#        [ 4.24234509e+00],
#        [ 3.60513181e+00],
#        [ 4.86381416e+00],
#        [ 3.41642330e+00],
#        [ 5.44592178e+00],
#        [ 5.16509920e+00],
#        [ 4.58396518e+00],
#        [ 4.55617605e+00],
#        [ 4.57704101e+00],
#        [ 6.11248578e+00],
#        [ 3.89908807e+00],
#        [ 5.05446965e+00],
#        [ 3.24856352e+00],
#        [ 5.28022564e+00],
#        [ 3.24584704e+00],
#        [ 5.50648524e+00],
#        [ 6.93305697e+00],
#        [ 4.39940523e+00],
#        [ 6.45107000e+00],
#        [ 4.39143514e+00],
#        [ 4.82355212e+00],
#        [ 5.34249428e+00],
#        [ 5.91699973e+00],
#        [ 5.94150611e+00],
#        [ 4.03404168e+00],
#        [ 4.81215663e+00],
#        [ 4.64994194e+00],
#        [ 4.08538794e+00],
#        [ 5.16088086e+00],
#        [ 4.23484485e+00],
#        [ 4.24097650e+00],
#        [ 2.43747201e+00],
#        [ 3.97365363e+00],
#        [ 4.97073771e+00],
#        [ 5.15166475e+00],
#        [ 5.23373573e+00],
#        [ 6.06551672e+00],
#        [ 4.30822122e+00],
#        [ 4.21390119e+00],
#        [ 5.39308331e+00],
#        [ 6.06962121e+00],
#        [ 6.69183516e+00],
#        [ 5.09412797e+00],
#        [ 4.20070278e+00],
#        [ 3.86368932e+00],
#        [ 3.21725432e+00],
#        [ 4.82793993e+00],
#        [ 3.19396831e+00],
#        [ 6.37688459e+00],
#        [ 4.59367153e+00],
#        [ 5.03003631e+00],
#        [ 4.95153510e+00],
#        [ 5.89353589e+00],
#        [ 4.62622501e+00],
#        [ 4.89741279e+00],
#        [ 5.52992117e+00],
#        [ 5.30632203e+00],
#        [ 5.45979987e+00],
#        [ 2.44991050e+00],
#        [ 4.21874449e+00],
#        [ 5.04462689e+00],
#        [ 4.45791693e+00],
#        [ 5.09398721e+00],
#        [ 4.50623880e+00],
#        [ 5.50055883e+00],
#        [ 5.45291729e+00],
#        [ 6.05049035e+00],
#        [ 4.67604627e+00],
#        [ 4.03514799e+00],
#        [ 3.89074218e+00],
#        [ 5.16400501e+00],
#        [ 4.83408106e+00],
#        [ 4.58072392e+00],
#        [ 5.08835803e+00],
#        [ 5.46722046e+00],
#        [ 6.10867596e+00],
#        [ 5.37988695e+00],
#        [ 5.37559471e+00],
#        [ 4.32933218e+00],
#        [ 3.77049769e+00],
#        [ 3.94122722e+00],
#        [ 5.34885254e+00],
#        [ 4.44339144e+00],
#        [ 5.45793435e+00],
#        [ 3.79887993e+00],
#        [ 6.50313595e+00],
#        [ 3.73548525e+00],
#        [ 3.40190192e+00],
#        [ 5.01284282e+00],
#        [ 5.92005985e+00],
#        [ 4.95611496e+00],
#        [ 5.41557761e+00],
#        [ 4.56652527e+00],
#        [ 5.82490602e+00],
#        [ 5.33405018e+00],
#        [ 5.32310684e+00],
#        [ 2.97930038e+00],
#        [ 4.83160861e+00],
#        [ 3.22083146e+00],
#        [ 6.41244584e+00],
#        [ 5.68660665e+00],
#        [ 3.50154012e+00],
#        [ 5.31667068e+00],
#        [ 4.46708335e+00],
#        [ 4.19035391e+00],
#        [ 4.94811215e+00],
#        [ 4.36649140e+00],
#        [ 4.61455949e+00],
#        [ 4.30660973e+00],
#        [ 4.60117075e+00],
#        [ 5.41777553e+00],
#        [ 5.41231553e+00],
#        [ 5.52645974e+00],
#        [ 4.66787450e+00],
#        [ 6.97315316e+00],
#        [ 5.18624980e+00],
#        [ 5.65674415e+00],
#        [ 5.24694415e+00],
#        [ 3.32833640e+00],
#        [ 4.87424231e+00],
#        [ 4.03957688e+00],
#        [ 4.94639168e+00],
#        [ 4.52619822e+00],
#        [ 3.52793389e+00],
#        [ 4.21169286e+00],
#        [ 3.83057661e+00],
#        [ 4.21668585e+00],
#        [ 5.79969570e+00],
#        [ 5.06210160e+00],
#        [ 4.60476933e+00],
#        [ 3.93742330e+00],
#        [ 5.59585804e+00],
#        [ 3.58387158e+00],
#        [ 5.33025045e+00],
#        [ 5.91508652e+00],
#        [ 4.04819828e+00],
#        [ 5.89150636e+00],
#        [ 7.08350384e+00],
#        [ 6.26429157e+00],
#        [ 6.37442015e+00],
#        [ 4.49056310e+00],
#        [ 6.86244067e+00],
#        [ 5.88777733e+00],
#        [ 3.35949937e+00],
#        [ 5.03215196e+00],
#        [ 6.37936732e+00],
#        [ 4.60034094e+00],
#        [ 4.55398941e+00],
#        [ 5.97543848e+00],
#        [ 3.41532505e+00],
#        [ 4.51409246e+00],
#        [ 6.21577813e+00],
#        [ 6.00051745e+00],
#        [ 4.42123550e+00],
#        [ 4.03804533e+00],
#        [ 5.40648875e+00],
#        [ 5.08791551e+00],
#        [ 4.74799277e+00],
#        [ 5.29757687e+00],
#        [ 6.35889850e+00],
#        [ 6.66876952e+00],
#        [ 4.81995032e+00],
#        [ 4.36954501e+00],
#        [ 3.52873709e+00],
#        [ 4.57763060e+00],
#        [ 3.41356173e+00],
#        [ 4.44306214e+00],
#        [ 4.29922888e+00],
#        [ 6.62513497e+00]])

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lesson, we saw how to check for normality (and other distributions) using one- and two-sample K-S tests. You are encouraged to use this test for all the upcoming algorithms and techniques that require a normality assumption. We saw that we can actually make assumptions for different distributions by providing the correct CDF function into Scipy K-S test functions.
